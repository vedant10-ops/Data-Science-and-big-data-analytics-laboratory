# %%
import pandas as pd

# Assuming 'demo.csv' is the dataset file in your working directory
df = pd.read_csv('demo.csv')
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
plt.title("Boxplot of the Dataset")
plt.ylim(0,215)
plt.show()

# %%
# Calculate the 10th and 90th percentile values for each column
percentiles = df.quantile([0.10, 0.90])

# Apply quantile-based flooring and capping
for column in df.columns:
    q10 = percentiles.loc[0.10, column]
    q90 = percentiles.loc[0.90, column]
    df[column] = df[column].apply(lambda x: q10 if x < q10 else (q90 if x > q90 else x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Calculate the 10th and 90th percentile values for each column
# ----> 2 percentiles = df.quantile([0.10, 0.90])
#       4 # Apply quantile-based flooring and capping
#       5 for column in df.columns:
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
plt.title("Boxplot of the Dataset")
plt.ylim(0,215)
plt.show()
